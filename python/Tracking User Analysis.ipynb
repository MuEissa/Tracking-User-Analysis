# %%
import pandas as pd 
import matplotlib as plt
import seaborn as sns

# %%
free_21 = pd.read_csv(r"C:\Users\Mustafa Eissa\Desktop\Analysis project\minutes_watched_2021_free.csv")
paid_21 = pd.read_csv(r"C:\Users\Mustafa Eissa\Desktop\Analysis project\minutes_watched_2021_paid.csv")
free_22 = pd.read_csv(r"C:\Users\Mustafa Eissa\Desktop\Analysis project\minutes_watched_2022_free.csv")
paid_22 = pd.read_csv(r"C:\Users\Mustafa Eissa\Desktop\Analysis project\minutes_watched_2022_paid.csv")

# %%
free_21.head()
# Out:
#    student_id  minutes_watched  paid_in_q2
# 0         767           0.0500           0
# 1         902          34.6167           0
# 2        1067           0.2667           0
# 3        1151         122.3500           0
# 4        1395         133.5167           0

# %%
free_22.head()
# Out:
#    student_id  minutes_watched  paid_in_q2
# 0         389           0.1500           0
# 1         666           2.8333           0
# 2         801        5732.5833           0
# 3         875          46.7667           0
# 4        1357           0.1167           0

# %%
paid_21.head()
# Out:
#    student_id  minutes_watched  paid_in_q2
# 0           6          81.0333           1
# 1         516          46.2667           1
# 2         520          91.1833           1
# 3         523        1322.2500           1
# 4         594           3.7333           1

# %%
paid_22.head()
# Out:
#    student_id  minutes_watched  paid_in_q2
# 0           6          67.0833           1
# 1         616         116.0167           1
# 2         618         238.1500           1
# 3         699         222.3500           1
# 4         702           1.6000           1

# %%
free_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5334 entries, 0 to 5333
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   student_id       5334 non-null   int64
#  1   minutes_watched  5334 non-null   float64
#  2   paid_in_q2       5334 non-null   int64
# dtypes: float64(1), int64(2)
# memory usage: 125.1 KB

# %%
 sns.kdeplot(free_21['minutes_watched'])
# Out:
# C:\Users\Mustafa Eissa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='minutes_watched', ylabel='Density'>

# %%
 sns.kdeplot(paid_21['minutes_watched'])
# Out:
# C:\Users\Mustafa Eissa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='minutes_watched', ylabel='Density'>

# %%
 sns.kdeplot(free_22['minutes_watched'])
# Out:
# C:\Users\Mustafa Eissa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='minutes_watched', ylabel='Density'>

# %%
d = sns.kdeplot(paid_22['minutes_watched'])
d
# Out:
# C:\Users\Mustafa Eissa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='minutes_watched', ylabel='Density'>

# %%
free_21 = free_21[free_21['minutes_watched']<free_21['minutes_watched'].quantile(.99)]
free_22 = free_22[free_22['minutes_watched']<free_22['minutes_watched'].quantile(.99)]
paid_21 = paid_21[paid_21['minutes_watched']<paid_21['minutes_watched'].quantile(.99)]
paid_22 = paid_22[paid_22['minutes_watched']<paid_22['minutes_watched'].quantile(.99)]

# %%
sns.kdeplot(free_21['minutes_watched']) 
# After removing the outlier
# Out:
# C:\Users\Mustafa Eissa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='minutes_watched', ylabel='Density'>

# %%
sns.kdeplot(paid_21['minutes_watched'])
# After removing the outlier
# Out:
# C:\Users\Mustafa Eissa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='minutes_watched', ylabel='Density'>

# %%
sns.kdeplot(free_22['minutes_watched'])
# After removing the outlier
# Out:
# C:\Users\Mustafa Eissa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='minutes_watched', ylabel='Density'>

# %%
sns.kdeplot(paid_22['minutes_watched'])
# After removing the outlier
# Out:
# C:\Users\Mustafa Eissa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='minutes_watched', ylabel='Density'>

# %%
free_21.to_csv('minutes_watched_21_free.csv', index=False)
paid_21.to_csv('minutes_watched_21_paid.csv', index=False)
free_22.to_csv('minutes_watched_22_free.csv', index=False)
paid_22.to_csv('minutes_watched_22_paid.csv', index=False)

# %%
import matplotlib.pyplot as plt
# Out:
# <Axes: xlabel='minutes_watched', ylabel='Density'>
